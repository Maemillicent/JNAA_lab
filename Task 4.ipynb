# %% [markdown]
# ACTIVITY 4
# =
#
# 1.Read Kumasi, Accra, Kete_krachi and Wa dataset using pandas.
# Rename the columns to suit the column elements
#
# 2.Create a datetime using the columns containing, year, month and day.
#
# 3.Find the annual rainfall total of all the datasets and visualise all the stations data in one figure
#
# 4.Find the annual Rainfall anomalies for each station
#
# 5.Visualise the yearly rainfall anomalies for each station by creating a subplot of 2 rows and 2 columns (each axis conatinaing visualisation for each station data)
#
# 6.Save your graph as pdf
#
# NB:
# make sure you label all graphs
# Make use of comments and the markdown to make your script look presentable

# %%
# importing packages

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# reading the files
Ksi= pd.read_fwf("Kumasi_1983_2017_dRR_gapless.txt", header=None)
Acc= pd.read_fwf("Accra_1983_2017_dRR_gapless.txt", header=None)
Kete_K= pd.read_fwf("Kete_Krachi_1983_2017_dRR_gapless.txt", header=None)
Wa= pd.read_fwf("Wa_1983_2017_dRR_gapless.txt", header=None)
# Wa
# Out:
#           0   1   2    3
# 0      1983   1   1  0.0
# 1      1983   1   2  0.0
# 2      1983   1   3  0.0
# 3      1983   1   4  0.0
# 4      1983   1   5  0.0
# ...     ...  ..  ..  ...
# 12779  2017  12  27  0.0
# 12780  2017  12  28  0.0
# 12781  2017  12  29  0.0
# 12782  2017  12  30  0.0
# 12783  2017  12  31  0.0
#
# [12784 rows x 4 columns]

# %%
# naming columns
Ksi.columns = ['Year', 'Month', 'Day', 'Precip']
Ksi
# Out:
#        Year  Month  Day  Precip
# 0      1983      1    1     0.0
# 1      1983      1    2     0.0
# 2      1983      1    3     0.0
# 3      1983      1    4     0.0
# 4      1983      1    5     0.0
# ...     ...    ...  ...     ...
# 12779  2017     12   27     0.0
# 12780  2017     12   28     0.0
# 12781  2017     12   29     0.0
# 12782  2017     12   30     0.0
# 12783  2017     12   31     0.0
#
# [12784 rows x 4 columns]

# %%
# Ksi['date'] = pd.to_datetime(Ksi[['Year', 'Month', 'Day']]) 
# Ksi

# %%
# dropping the year, month, day
Ksi.drop(['Year', 'Month', 'Day'], axis=1, inplace=True)

# %%
Ksi
# Out:
#        Precip       date
# 0         0.0 1983-01-01
# 1         0.0 1983-01-02
# 2         0.0 1983-01-03
# 3         0.0 1983-01-04
# 4         0.0 1983-01-05
# ...       ...        ...
# 12779     0.0 2017-12-27
# 12780     0.0 2017-12-28
# 12781     0.0 2017-12-29
# 12782     0.0 2017-12-30
# 12783     0.0 2017-12-31
#
# [12784 rows x 2 columns]

# %%
# setting the date as index
Ksi.plot()
# Out:
# <AxesSubplot:>

# %%
Kum = Ksi.set_index(pd.DatetimeIndex(Ksi['date']))
# Kum = Ksi.resample("M").mean()
help(resample)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:41, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 Kum = Ksi.set_index(pd.DatetimeIndex(Ksi['date']))
# ...

# %%
Kum.resample('M', on='date').sum()
# Out:
#             Precip
# date
# 1983-01-31     0.0
# 1983-02-28    34.0
# 1983-03-31    67.0
# 1983-04-30    84.4
# 1983-05-31   116.2
# ...            ...
# 2017-08-31    91.8
# 2017-09-30   238.6
# 2017-10-31   169.8
# 2017-11-30    80.0
# 2017-12-31    50.4
#
# [420 rows x 1 columns]

# %%
# Kum['date'] = pd.to_numeric(Kum['date'], errors='coerce')

# plt.plot(Kum)
# plt.plot(kum)

Kum.resample('Y',on='date').sum()
# Out:
#              Precip
# date
# 1983-12-31   906.00
# 1984-12-31  1283.90
# 1985-12-31  1669.20
# 1986-12-31  1132.60
# 1987-12-31  1303.60
# 1988-12-31  1420.40
# 1989-12-31  1463.90
# 1990-12-31  1219.20
# 1991-12-31  1275.80
# 1992-12-31   963.50
# 1993-12-31  1399.85
# 1994-12-31  1111.10
# 1995-12-31  1327.20
# 1996-12-31  1040.90
# 1997-12-31  1303.70
# 1998-12-31  1092.20
# 1999-12-31  1428.90
# 2000-12-31  1488.50
# 2001-12-31  1185.80
# 2002-12-31  1568.30
# 2003-12-31  1349.20
# 2004-12-31  1415.30
# 2005-12-31  1231.00
# 2006-12-31  1159.80
# 2007-12-31  1794.90
# 2008-12-31  1452.00
# 2009-12-31  1530.70
# 2010-12-31  1197.50
# 2011-12-31  1521.80
# 2012-12-31  1521.40
# 2013-12-31  1348.70
# 2014-12-31  1354.20
# 2015-12-31  1234.80
# 2016-12-31  1333.30
# 2017-12-31  1476.00

# %%
# fig, Kum = plt.subplots(figsize=(10, 5))

# Kum.plot(date[:, 0], Precip[:, 1],) #color="green", lw=1.5, ls="--", marker="*", label="Jan") #We specify some extra attributes here
# # ax.plot(temp[:, 0], temp[:, 2], color="red", lw=1.5, ls="--", marker="*", label="Feb")

# %%
# # Generate bars
# Kum.plot(date[:, 0], Precip[:, 1], color="green", lw=1.5, ls="--", marker="*", label="Jan")# fig, axes = plt.subplots(ncols=2, figsize=(10, 5))
Kum.plot(Precip[:, 1], color="green", lw=1.5, ls="--", marker="*", label="Jan")# fig, axes = plt.subplots(ncols=2, figsize=(10, 5))

# Kum = axes[0]
# Kum.bar(date, precip)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 3>()
#       1 # # Generate bars
#       2 # Kum.plot(date[:, 0], Precip[:, 1], color="green", lw=1.5, ls="--", marker="*", label="Jan")# fig, axes = plt.subplots(ncols=2, figsize=(10, 5))
# ----> 3 Kum.plot(Precip[:, 1], color="green", lw=1.5, ls="--", marker="*", label="Jan")
#
# NameError: name 'Precip' is not defined

# %%
plt.plot(Kum)
